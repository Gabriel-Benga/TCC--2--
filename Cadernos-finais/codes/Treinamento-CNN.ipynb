# %%
from tensorflow import keras
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.preprocessing import image
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense, BatchNormalization, Dropout, Flatten, Conv2D, MaxPooling2D
from tensorflow.keras.optimizers import Adam
import numpy as np
import random
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
TRAINING_DIR = r'C:\Users\Gabriel Benga\Documents\Python\TCC\TCC\TCC\Datasets\df1-banco com varias posicoes de mao com diferentes ambientes tbm\train'
TEST_DIR = r'C:\Users\Gabriel Benga\Documents\Python\TCC\TCC\TCC\Datasets\df1-banco com varias posicoes de mao com diferentes ambientes tbm\test'
im_shape = (64, 64)
seed = 10
BATCH_SIZE = 64

# %%
#Using keras ImageGenerator and flow_from_directoty

# Subdivision in test/validation
data_generator = ImageDataGenerator(rescale=1./255, validation_split=0.2)
val_data_generator = ImageDataGenerator(rescale=1./255, validation_split=0.2)

# %%
data_generator = ImageDataGenerator(
        validation_split=0.2,
        rotation_range=20,
        width_shift_range=0.2,
        height_shift_range=0.2,
        rescale=1./255,
        shear_range=0.2,
        zoom_range=0.2,
        horizontal_flip=True,
        fill_mode='nearest')

val_data_generator = ImageDataGenerator(rescale=1./255, validation_split=0.2)

# %%
# Generator para parte train
train_generator = data_generator.flow_from_directory(TRAINING_DIR, target_size=im_shape, shuffle=True, seed=seed,
                                                     class_mode='categorical', batch_size=BATCH_SIZE, subset="training")
# Generator para parte validação
validation_generator = val_data_generator.flow_from_directory(TRAINING_DIR, target_size=im_shape, shuffle=False, seed=seed,
                                                     class_mode='categorical', batch_size=BATCH_SIZE, subset="validation")

# Generator para dataset de teste
test_generator = ImageDataGenerator(rescale=1./255)
test_generator = test_generator.flow_from_directory(TEST_DIR, target_size=im_shape, shuffle=False, seed=seed,
                                                     class_mode='categorical', batch_size=BATCH_SIZE)

nb_train_samples = train_generator.samples
nb_validation_samples = validation_generator.samples
nb_test_samples = test_generator.samples
classes = list(train_generator.class_indices.keys())
print('Classes: '+str(classes))
num_classes  = len(classes)
# Out:
# Found 27774 images belonging to 21 classes.
# Found 6940 images belonging to 21 classes.
# Found 11548 images belonging to 21 classes.
# Classes: ['A', 'B', 'C', 'D', 'E', 'F', 'G', 'I', 'L', 'M', 'N', 'O', 'P', 'Q', 'R', 'S', 'T', 'U', 'V', 'W', 'Y']

# %%
# Visualizing some examples
plt.figure(figsize=(15,15))
for i in range(9):
    plt.subplot(330 + 1 + i)
    batch = next(train_generator)[0] * 255  # Corrigido para usar next() com o iterador
    image = batch[0].astype('uint8')
    plt.imshow(image)
plt.show()

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Dropout, Flatten, Dense, Input
from keras.optimizers import Adam

# %%
model = Sequential()
model.add(Input(shape=(im_shape[0], im_shape[1], 3)))
model.add(Conv2D(32, kernel_size=(3, 3), activation='relu'))

model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.2))

model.add(Conv2D(32, kernel_size=(3, 3), activation='tanh'))
model.add(Dropout(0.2))

model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.2))

model.add(Conv2D(64, kernel_size=(3, 3), activation='tanh'))

model.add(Conv2D(64, kernel_size=(3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Flatten())
model.add(Dense(512, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(num_classes, activation='softmax'))
model.summary()

# Compila o modelo
model.compile(loss='categorical_crossentropy',
              optimizer=Adam(),
              metrics=['accuracy'])
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d_4 (Conv2D)                    │ (None, 62, 62, 32)          │             896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_3 (MaxPooling2D)       │ (None, 31, 31, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_4 (Dropout)                  │ (None, 31, 31, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_5 (Conv2D)                    │ (None, 29, 29, 32)          │           9,248 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_5 (Dropout)                  │ (None, 29, 29, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_4 (MaxPooling2D)       │ (None, 14, 14, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_6 (Dropout)                  │ (None, 14, 14, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_6 (Conv2D)                    │ (None, 12, 12, 64)          │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_7 (Conv2D)                    │ (None, 10, 10, 64)          │          36,928 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_5 (MaxPooling2D)       │ (None, 5, 5, 64)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten_1 (Flatten)                  │ (None, 1600)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 512)                 │         819,712 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_7 (Dropout)                  │ (None, 512)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 21)                  │          10,773 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 896,053 (3.42 MB)
#  Trainable params: 896,053 (3.42 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
epochs = 100

#Callback to save the best model
callbacks_list = [
    keras.callbacks.ModelCheckpoint(
        filepath='modelo-treimado.keras',
        monitor='val_loss', save_best_only=True, verbose=1),
    keras.callbacks.EarlyStopping(monitor='val_loss', patience=30,verbose=1)
]

#Training
history = model.fit(
        train_generator,
        steps_per_epoch=nb_train_samples // BATCH_SIZE,
        epochs=epochs,
        callbacks = callbacks_list,
        validation_data=validation_generator,
        verbose = 1,
        validation_steps=nb_validation_samples // BATCH_SIZE)
# Out:
# Epoch 1/100
# C:\Users\Gabriel Benga\Documents\Python\Python-sistemas\Anaconda\Lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - accuracy: 0.1218 - loss: 2.7924
# Epoch 1: val_loss improved from inf to 1.21586, saving model to modelo-treimado.keras
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 69s 151ms/step - accuracy: 0.1221 - loss: 2.7913 - val_accuracy: 0.5939 - val_loss: 1.2159
# Epoch 2/100
#   1/433 ━━━━━━━━━━━━━━━━━━━━ 21s 50ms/step - accuracy: 0.4688 - loss: 1.5146
# Epoch 2: val_loss did not improve from 1.21586
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 0s 161us/step - accuracy: 0.4688 - loss: 1.5146 - val_accuracy: 0.0000e+00 - val_loss: 3.3777
# Epoch 3/100
# C:\Users\Gabriel Benga\Documents\Python\Python-sistemas\Anaconda\Lib\contextlib.py:158: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self.gen.throw(typ, value, traceback)
# 432/433 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 0.5997 - loss: 1.1197
# Epoch 3: val_loss did not improve from 1.21586
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 47s 106ms/step - accuracy: 0.5999 - loss: 1.1190 - val_accuracy: 0.6615 - val_loss: 1.2734
# Epoch 4/100
#   1/433 ━━━━━━━━━━━━━━━━━━━━ 17s 40ms/step - accuracy: 0.7812 - loss: 0.7045
# Epoch 4: val_loss did not improve from 1.21586
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 0s 93us/step - accuracy: 0.7812 - loss: 0.7045 - val_accuracy: 0.0714 - val_loss: 3.3824
# Epoch 5/100
# 432/433 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - accuracy: 0.7370 - loss: 0.7338
# Epoch 5: val_loss did not improve from 1.21586
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 48s 109ms/step - accuracy: 0.7371 - loss: 0.7336 - val_accuracy: 0.5767 - val_loss: 1.6174
# Epoch 6/100
#   1/433 ━━━━━━━━━━━━━━━━━━━━ 20s 47ms/step - accuracy: 0.7656 - loss: 0.4920
# Epoch 6: val_loss did not improve from 1.21586
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 0s 124us/step - accuracy: 0.7656 - loss: 0.4920 - val_accuracy: 0.0357 - val_loss: 3.3113
# Epoch 7/100
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 0.8026 - loss: 0.5539
# Epoch 7: val_loss improved from 1.21586 to 0.75692, saving model to modelo-treimado.keras
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 46s 105ms/step - accuracy: 0.8026 - loss: 0.5538 - val_accuracy: 0.7801 - val_loss: 0.7569
# Epoch 8/100
#   1/433 ━━━━━━━━━━━━━━━━━━━━ 21s 50ms/step - accuracy: 0.8438 - loss: 0.5140
# Epoch 8: val_loss improved from 0.75692 to 0.18405, saving model to modelo-treimado.keras
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 0s 188us/step - accuracy: 0.8438 - loss: 0.5140 - val_accuracy: 1.0000 - val_loss: 0.1841
# Epoch 9/100
# 432/433 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - accuracy: 0.8406 - loss: 0.4484
# Epoch 9: val_loss did not improve from 0.18405
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 49s 111ms/step - accuracy: 0.8406 - loss: 0.4484 - val_accuracy: 0.7344 - val_loss: 0.9171
# Epoch 10/100
#   1/433 ━━━━━━━━━━━━━━━━━━━━ 23s 55ms/step - accuracy: 0.9531 - loss: 0.2028
# Epoch 10: val_loss did not improve from 0.18405
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 0s 104us/step - accuracy: 0.9531 - loss: 0.2028 - val_accuracy: 0.5000 - val_loss: 2.9901
# Epoch 11/100
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - accuracy: 0.8645 - loss: 0.3851
# Epoch 11: val_loss did not improve from 0.18405
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 48s 109ms/step - accuracy: 0.8645 - loss: 0.3851 - val_accuracy: 0.7477 - val_loss: 0.8629
# Epoch 12/100
#   1/433 ━━━━━━━━━━━━━━━━━━━━ 21s 50ms/step - accuracy: 0.8750 - loss: 0.3557
# Epoch 12: val_loss improved from 0.18405 to 0.02714, saving model to modelo-treimado.keras
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 0s 218us/step - accuracy: 0.8750 - loss: 0.3557 - val_accuracy: 1.0000 - val_loss: 0.0271
# Epoch 13/100
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 0.8748 - loss: 0.3479
# Epoch 13: val_loss did not improve from 0.02714
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 47s 108ms/step - accuracy: 0.8748 - loss: 0.3479 - val_accuracy: 0.7477 - val_loss: 0.8649
# Epoch 14/100
#   1/433 ━━━━━━━━━━━━━━━━━━━━ 20s 47ms/step - accuracy: 0.9062 - loss: 0.3374
# Epoch 14: val_loss did not improve from 0.02714
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 0s 98us/step - accuracy: 0.9062 - loss: 0.3374 - val_accuracy: 0.7857 - val_loss: 0.3625
# Epoch 15/100
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 0.8915 - loss: 0.3196
# Epoch 15: val_loss did not improve from 0.02714
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 47s 107ms/step - accuracy: 0.8915 - loss: 0.3196 - val_accuracy: 0.6338 - val_loss: 2.1979
# Epoch 16/100
#   1/433 ━━━━━━━━━━━━━━━━━━━━ 14s 34ms/step - accuracy: 0.8438 - loss: 0.3785
# Epoch 16: val_loss did not improve from 0.02714
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 0s 128us/step - accuracy: 0.8438 - loss: 0.3785 - val_accuracy: 0.5000 - val_loss: 6.0939
# Epoch 17/100
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - accuracy: 0.9014 - loss: 0.2843
# Epoch 17: val_loss did not improve from 0.02714
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 46s 105ms/step - accuracy: 0.9014 - loss: 0.2842 - val_accuracy: 0.7574 - val_loss: 1.1557
# Epoch 18/100
#   1/433 ━━━━━━━━━━━━━━━━━━━━ 25s 58ms/step - accuracy: 0.8871 - loss: 0.3433
# Epoch 18: val_loss did not improve from 0.02714
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 0s 100us/step - accuracy: 0.8871 - loss: 0.3433 - val_accuracy: 0.9643 - val_loss: 0.1042
# Epoch 19/100
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - accuracy: 0.9108 - loss: 0.2583
# Epoch 19: val_loss did not improve from 0.02714
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 48s 109ms/step - accuracy: 0.9108 - loss: 0.2583 - val_accuracy: 0.8199 - val_loss: 0.6724
# Epoch 20/100
#   1/433 ━━━━━━━━━━━━━━━━━━━━ 24s 56ms/step - accuracy: 0.9219 - loss: 0.1980
# Epoch 20: val_loss improved from 0.02714 to 0.00616, saving model to modelo-treimado.keras
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 0s 209us/step - accuracy: 0.9219 - loss: 0.1980 - val_accuracy: 1.0000 - val_loss: 0.0062
# Epoch 21/100
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - accuracy: 0.9162 - loss: 0.2421
# Epoch 21: val_loss did not improve from 0.00616
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 58s 132ms/step - accuracy: 0.9162 - loss: 0.2421 - val_accuracy: 0.7130 - val_loss: 1.4076
# Epoch 22/100
#   1/433 ━━━━━━━━━━━━━━━━━━━━ 24s 57ms/step - accuracy: 0.9219 - loss: 0.2147
# Epoch 22: val_loss did not improve from 0.00616
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 0s 104us/step - accuracy: 0.9219 - loss: 0.2147 - val_accuracy: 0.1429 - val_loss: 6.5490
# Epoch 23/100
# 432/433 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - accuracy: 0.9164 - loss: 0.2388
# Epoch 23: val_loss did not improve from 0.00616
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 51s 115ms/step - accuracy: 0.9164 - loss: 0.2387 - val_accuracy: 0.8034 - val_loss: 0.9211
# Epoch 24/100
#   1/433 ━━━━━━━━━━━━━━━━━━━━ 21s 49ms/step - accuracy: 0.9062 - loss: 0.3306
# Epoch 24: val_loss did not improve from 0.00616
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 0s 103us/step - accuracy: 0.9062 - loss: 0.3306 - val_accuracy: 0.7500 - val_loss: 0.3648
# Epoch 25/100
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - accuracy: 0.9261 - loss: 0.2108
# Epoch 25: val_loss did not improve from 0.00616
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 49s 112ms/step - accuracy: 0.9261 - loss: 0.2108 - val_accuracy: 0.8073 - val_loss: 0.7015
# Epoch 26/100
#   1/433 ━━━━━━━━━━━━━━━━━━━━ 23s 55ms/step - accuracy: 0.9844 - loss: 0.0626
# Epoch 26: val_loss improved from 0.00616 to 0.00042, saving model to modelo-treimado.keras
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 0s 204us/step - accuracy: 0.9844 - loss: 0.0626 - val_accuracy: 1.0000 - val_loss: 4.2020e-04
# Epoch 27/100
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - accuracy: 0.9311 - loss: 0.1941
# Epoch 27: val_loss did not improve from 0.00042
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 49s 111ms/step - accuracy: 0.9311 - loss: 0.1941 - val_accuracy: 0.8999 - val_loss: 0.2995
# Epoch 28/100
#   1/433 ━━━━━━━━━━━━━━━━━━━━ 21s 50ms/step - accuracy: 0.8750 - loss: 0.4059
# Epoch 28: val_loss did not improve from 0.00042
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 0s 104us/step - accuracy: 0.8750 - loss: 0.4059 - val_accuracy: 1.0000 - val_loss: 6.8453e-04
# Epoch 29/100
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - accuracy: 0.9369 - loss: 0.1817
# Epoch 29: val_loss did not improve from 0.00042
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 50s 114ms/step - accuracy: 0.9369 - loss: 0.1817 - val_accuracy: 0.8614 - val_loss: 0.6797
# Epoch 30/100
#   1/433 ━━━━━━━━━━━━━━━━━━━━ 21s 50ms/step - accuracy: 0.9688 - loss: 0.1495
# Epoch 30: val_loss did not improve from 0.00042
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 0s 99us/step - accuracy: 0.9688 - loss: 0.1495 - val_accuracy: 1.0000 - val_loss: 0.0042
# Epoch 31/100
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - accuracy: 0.9369 - loss: 0.1842
# Epoch 31: val_loss did not improve from 0.00042
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 50s 114ms/step - accuracy: 0.9369 - loss: 0.1842 - val_accuracy: 0.9437 - val_loss: 0.3419
# Epoch 32/100
#   1/433 ━━━━━━━━━━━━━━━━━━━━ 19s 46ms/step - accuracy: 0.9375 - loss: 0.2101
# Epoch 32: val_loss did not improve from 0.00042
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 0s 101us/step - accuracy: 0.9375 - loss: 0.2101 - val_accuracy: 1.0000 - val_loss: 0.0015
# Epoch 33/100
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - accuracy: 0.9439 - loss: 0.1642
# Epoch 33: val_loss did not improve from 0.00042
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 48s 109ms/step - accuracy: 0.9439 - loss: 0.1642 - val_accuracy: 0.8747 - val_loss: 0.5125
# Epoch 34/100
#   1/433 ━━━━━━━━━━━━━━━━━━━━ 21s 50ms/step - accuracy: 0.9375 - loss: 0.2175
# Epoch 34: val_loss did not improve from 0.00042
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 0s 82us/step - accuracy: 0.9375 - loss: 0.2175 - val_accuracy: 1.0000 - val_loss: 0.0022
# Epoch 35/100
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - accuracy: 0.9428 - loss: 0.1739
# Epoch 35: val_loss did not improve from 0.00042
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 50s 114ms/step - accuracy: 0.9428 - loss: 0.1739 - val_accuracy: 0.8776 - val_loss: 0.5600
# Epoch 36/100
#   1/433 ━━━━━━━━━━━━━━━━━━━━ 23s 54ms/step - accuracy: 0.9219 - loss: 0.3010
# Epoch 36: val_loss did not improve from 0.00042
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 0s 103us/step - accuracy: 0.9219 - loss: 0.3010 - val_accuracy: 1.0000 - val_loss: 0.0137
# Epoch 37/100
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - accuracy: 0.9469 - loss: 0.1581
# Epoch 37: val_loss did not improve from 0.00042
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 49s 111ms/step - accuracy: 0.9469 - loss: 0.1581 - val_accuracy: 0.8958 - val_loss: 0.3650
# Epoch 38/100
#   1/433 ━━━━━━━━━━━━━━━━━━━━ 24s 56ms/step - accuracy: 0.9219 - loss: 0.2054
# Epoch 38: val_loss improved from 0.00042 to 0.00000, saving model to modelo-treimado.keras
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 0s 211us/step - accuracy: 0.9219 - loss: 0.2054 - val_accuracy: 1.0000 - val_loss: 1.8562e-06
# Epoch 39/100
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - accuracy: 0.9453 - loss: 0.1647
# Epoch 39: val_loss did not improve from 0.00000
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 49s 112ms/step - accuracy: 0.9453 - loss: 0.1647 - val_accuracy: 0.9272 - val_loss: 0.3371
# Epoch 40/100
#   1/433 ━━━━━━━━━━━━━━━━━━━━ 21s 51ms/step - accuracy: 0.9375 - loss: 0.1370
# Epoch 40: val_loss did not improve from 0.00000
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 0s 101us/step - accuracy: 0.9375 - loss: 0.1370 - val_accuracy: 1.0000 - val_loss: 2.0988e-04
# Epoch 41/100
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - accuracy: 0.9475 - loss: 0.1565
# Epoch 41: val_loss did not improve from 0.00000
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 50s 113ms/step - accuracy: 0.9475 - loss: 0.1565 - val_accuracy: 0.9265 - val_loss: 0.2901
# Epoch 42/100
#   1/433 ━━━━━━━━━━━━━━━━━━━━ 21s 50ms/step - accuracy: 0.9219 - loss: 0.2308
# Epoch 42: val_loss did not improve from 0.00000
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 0s 102us/step - accuracy: 0.9219 - loss: 0.2308 - val_accuracy: 1.0000 - val_loss: 0.0072
# Epoch 43/100
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - accuracy: 0.9534 - loss: 0.1406
# Epoch 43: val_loss did not improve from 0.00000
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 49s 112ms/step - accuracy: 0.9534 - loss: 0.1406 - val_accuracy: 0.8937 - val_loss: 0.2564
# Epoch 44/100
#   1/433 ━━━━━━━━━━━━━━━━━━━━ 21s 50ms/step - accuracy: 1.0000 - loss: 0.0396
# Epoch 44: val_loss did not improve from 0.00000
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 0s 100us/step - accuracy: 1.0000 - loss: 0.0396 - val_accuracy: 1.0000 - val_loss: 1.5849e-05
# Epoch 45/100
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - accuracy: 0.9569 - loss: 0.1304
# Epoch 45: val_loss did not improve from 0.00000
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 50s 115ms/step - accuracy: 0.9569 - loss: 0.1305 - val_accuracy: 0.9323 - val_loss: 0.3071
# Epoch 46/100
#   1/433 ━━━━━━━━━━━━━━━━━━━━ 22s 52ms/step - accuracy: 0.9375 - loss: 0.1740
# Epoch 46: val_loss did not improve from 0.00000
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 0s 100us/step - accuracy: 0.9375 - loss: 0.1740 - val_accuracy: 1.0000 - val_loss: 5.6912e-05
# Epoch 47/100
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - accuracy: 0.9517 - loss: 0.1450
# Epoch 47: val_loss did not improve from 0.00000
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 50s 113ms/step - accuracy: 0.9517 - loss: 0.1450 - val_accuracy: 0.8650 - val_loss: 0.8463
# Epoch 48/100
#   1/433 ━━━━━━━━━━━━━━━━━━━━ 23s 54ms/step - accuracy: 0.9375 - loss: 0.1403
# Epoch 48: val_loss did not improve from 0.00000
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 0s 97us/step - accuracy: 0.9375 - loss: 0.1403 - val_accuracy: 1.0000 - val_loss: 2.5279e-04
# Epoch 49/100
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - accuracy: 0.9543 - loss: 0.1400
# Epoch 49: val_loss did not improve from 0.00000
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 49s 112ms/step - accuracy: 0.9543 - loss: 0.1400 - val_accuracy: 0.9165 - val_loss: 0.3135
# Epoch 50/100
#   1/433 ━━━━━━━━━━━━━━━━━━━━ 23s 55ms/step - accuracy: 0.9688 - loss: 0.1952
# Epoch 50: val_loss did not improve from 0.00000
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 0s 107us/step - accuracy: 0.9688 - loss: 0.1952 - val_accuracy: 1.0000 - val_loss: 2.2435e-04
# Epoch 51/100
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - accuracy: 0.9521 - loss: 0.1383
# Epoch 51: val_loss did not improve from 0.00000
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 50s 115ms/step - accuracy: 0.9521 - loss: 0.1383 - val_accuracy: 0.8984 - val_loss: 0.4255
# Epoch 52/100
#   1/433 ━━━━━━━━━━━━━━━━━━━━ 25s 59ms/step - accuracy: 0.9844 - loss: 0.0378
# Epoch 52: val_loss did not improve from 0.00000
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 0s 101us/step - accuracy: 0.9844 - loss: 0.0378 - val_accuracy: 1.0000 - val_loss: 6.4134e-04
# Epoch 53/100
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - accuracy: 0.9543 - loss: 0.1444
# Epoch 53: val_loss did not improve from 0.00000
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 48s 111ms/step - accuracy: 0.9543 - loss: 0.1444 - val_accuracy: 0.9361 - val_loss: 0.2908
# Epoch 54/100
#   1/433 ━━━━━━━━━━━━━━━━━━━━ 25s 59ms/step - accuracy: 0.9531 - loss: 0.1204
# Epoch 54: val_loss did not improve from 0.00000
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 0s 102us/step - accuracy: 0.9531 - loss: 0.1204 - val_accuracy: 1.0000 - val_loss: 1.8562e-06
# Epoch 55/100
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - accuracy: 0.9608 - loss: 0.1212
# Epoch 55: val_loss did not improve from 0.00000
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 48s 110ms/step - accuracy: 0.9608 - loss: 0.1212 - val_accuracy: 0.9259 - val_loss: 0.2494
# Epoch 56/100
#   1/433 ━━━━━━━━━━━━━━━━━━━━ 20s 48ms/step - accuracy: 0.9375 - loss: 0.1536
# Epoch 56: val_loss improved from 0.00000 to 0.00000, saving model to modelo-treimado.keras
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 0s 202us/step - accuracy: 0.9375 - loss: 0.1536 - val_accuracy: 1.0000 - val_loss: 2.0862e-07
# Epoch 57/100
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - accuracy: 0.9619 - loss: 0.1200
# Epoch 57: val_loss did not improve from 0.00000
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 49s 112ms/step - accuracy: 0.9619 - loss: 0.1200 - val_accuracy: 0.8896 - val_loss: 0.4279
# Epoch 58/100
#   1/433 ━━━━━━━━━━━━━━━━━━━━ 23s 53ms/step - accuracy: 0.9844 - loss: 0.0395
# Epoch 58: val_loss did not improve from 0.00000
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 0s 105us/step - accuracy: 0.9844 - loss: 0.0395 - val_accuracy: 1.0000 - val_loss: 5.2961e-06
# Epoch 59/100
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - accuracy: 0.9578 - loss: 0.1278
# Epoch 59: val_loss did not improve from 0.00000
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 50s 113ms/step - accuracy: 0.9578 - loss: 0.1278 - val_accuracy: 0.8394 - val_loss: 0.8546
# Epoch 60/100
#   1/433 ━━━━━━━━━━━━━━━━━━━━ 27s 65ms/step - accuracy: 0.9844 - loss: 0.0457
# Epoch 60: val_loss did not improve from 0.00000
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 0s 103us/step - accuracy: 0.9844 - loss: 0.0457 - val_accuracy: 0.9643 - val_loss: 0.0934
# Epoch 61/100
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - accuracy: 0.9604 - loss: 0.1210
# Epoch 61: val_loss did not improve from 0.00000
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 49s 112ms/step - accuracy: 0.9604 - loss: 0.1210 - val_accuracy: 0.9563 - val_loss: 0.1840
# Epoch 62/100
#   1/433 ━━━━━━━━━━━━━━━━━━━━ 21s 50ms/step - accuracy: 0.9531 - loss: 0.0864
# Epoch 62: val_loss did not improve from 0.00000
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 0s 99us/step - accuracy: 0.9531 - loss: 0.0864 - val_accuracy: 1.0000 - val_loss: 1.1515e-04
# Epoch 63/100
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - accuracy: 0.9622 - loss: 0.1157
# Epoch 63: val_loss did not improve from 0.00000
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 49s 112ms/step - accuracy: 0.9622 - loss: 0.1157 - val_accuracy: 0.9799 - val_loss: 0.0695
# Epoch 64/100
#   1/433 ━━━━━━━━━━━━━━━━━━━━ 20s 48ms/step - accuracy: 0.9688 - loss: 0.1291
# Epoch 64: val_loss did not improve from 0.00000
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 0s 102us/step - accuracy: 0.9688 - loss: 0.1291 - val_accuracy: 1.0000 - val_loss: 0.0016
# Epoch 65/100
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - accuracy: 0.9596 - loss: 0.1173
# Epoch 65: val_loss did not improve from 0.00000
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 50s 114ms/step - accuracy: 0.9596 - loss: 0.1172 - val_accuracy: 0.9096 - val_loss: 0.4458
# Epoch 66/100
#   1/433 ━━━━━━━━━━━━━━━━━━━━ 20s 47ms/step - accuracy: 0.9839 - loss: 0.0672
# Epoch 66: val_loss did not improve from 0.00000
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 0s 98us/step - accuracy: 0.9839 - loss: 0.0672 - val_accuracy: 1.0000 - val_loss: 3.7764e-06
# Epoch 67/100
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - accuracy: 0.9637 - loss: 0.1124
# Epoch 67: val_loss did not improve from 0.00000
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 50s 113ms/step - accuracy: 0.9637 - loss: 0.1124 - val_accuracy: 0.8698 - val_loss: 0.6581
# Epoch 68/100
#   1/433 ━━━━━━━━━━━━━━━━━━━━ 20s 48ms/step - accuracy: 0.9531 - loss: 0.0968
# Epoch 68: val_loss did not improve from 0.00000
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 0s 97us/step - accuracy: 0.9531 - loss: 0.0968 - val_accuracy: 1.0000 - val_loss: 0.0027
# Epoch 69/100
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - accuracy: 0.9635 - loss: 0.1100
# Epoch 69: val_loss did not improve from 0.00000
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 50s 115ms/step - accuracy: 0.9635 - loss: 0.1100 - val_accuracy: 0.9362 - val_loss: 0.2190
# Epoch 70/100
#   1/433 ━━━━━━━━━━━━━━━━━━━━ 23s 55ms/step - accuracy: 1.0000 - loss: 0.0267
# Epoch 70: val_loss did not improve from 0.00000
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 0s 113us/step - accuracy: 1.0000 - loss: 0.0267 - val_accuracy: 1.0000 - val_loss: 0.0043
# Epoch 71/100
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - accuracy: 0.9651 - loss: 0.1012
# Epoch 71: val_loss did not improve from 0.00000
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 50s 114ms/step - accuracy: 0.9651 - loss: 0.1012 - val_accuracy: 0.8497 - val_loss: 0.9502
# Epoch 72/100
#   1/433 ━━━━━━━━━━━━━━━━━━━━ 23s 55ms/step - accuracy: 0.9688 - loss: 0.0807
# Epoch 72: val_loss did not improve from 0.00000
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 0s 102us/step - accuracy: 0.9688 - loss: 0.0807 - val_accuracy: 1.0000 - val_loss: 0.0909
# Epoch 73/100
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - accuracy: 0.9681 - loss: 0.0991
# Epoch 73: val_loss did not improve from 0.00000
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 50s 115ms/step - accuracy: 0.9681 - loss: 0.0991 - val_accuracy: 0.9758 - val_loss: 0.0718
# Epoch 74/100
#   1/433 ━━━━━━━━━━━━━━━━━━━━ 22s 52ms/step - accuracy: 0.9844 - loss: 0.0356
# Epoch 74: val_loss improved from 0.00000 to 0.00000, saving model to modelo-treimado.keras
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 0s 227us/step - accuracy: 0.9844 - loss: 0.0356 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 75/100
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - accuracy: 0.9679 - loss: 0.1059
# Epoch 75: val_loss did not improve from 0.00000
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 51s 115ms/step - accuracy: 0.9679 - loss: 0.1059 - val_accuracy: 0.8892 - val_loss: 0.5474
# Epoch 76/100
#   1/433 ━━━━━━━━━━━━━━━━━━━━ 20s 48ms/step - accuracy: 0.9688 - loss: 0.1594
# Epoch 76: val_loss did not improve from 0.00000
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 0s 105us/step - accuracy: 0.9688 - loss: 0.1594 - val_accuracy: 1.0000 - val_loss: 0.0207
# Epoch 77/100
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - accuracy: 0.9646 - loss: 0.1113
# Epoch 77: val_loss did not improve from 0.00000
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 51s 117ms/step - accuracy: 0.9646 - loss: 0.1113 - val_accuracy: 0.9747 - val_loss: 0.0774
# Epoch 78/100
#   1/433 ━━━━━━━━━━━━━━━━━━━━ 31s 74ms/step - accuracy: 0.9375 - loss: 0.1448
# Epoch 78: val_loss did not improve from 0.00000
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 0s 141us/step - accuracy: 0.9375 - loss: 0.1448 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 79/100
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.9674 - loss: 0.1002
# Epoch 79: val_loss did not improve from 0.00000
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 51s 117ms/step - accuracy: 0.9674 - loss: 0.1002 - val_accuracy: 0.9301 - val_loss: 0.2864
# Epoch 80/100
#   1/433 ━━━━━━━━━━━━━━━━━━━━ 20s 47ms/step - accuracy: 0.9531 - loss: 0.0973
# Epoch 80: val_loss did not improve from 0.00000
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 0s 106us/step - accuracy: 0.9531 - loss: 0.0973 - val_accuracy: 1.0000 - val_loss: 4.8961e-07
# Epoch 81/100
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.9668 - loss: 0.0991
# Epoch 81: val_loss did not improve from 0.00000
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 51s 117ms/step - accuracy: 0.9668 - loss: 0.0991 - val_accuracy: 0.9531 - val_loss: 0.1899
# Epoch 82/100
#   1/433 ━━━━━━━━━━━━━━━━━━━━ 29s 68ms/step - accuracy: 1.0000 - loss: 0.0168
# Epoch 82: val_loss did not improve from 0.00000
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 0s 111us/step - accuracy: 1.0000 - loss: 0.0168 - val_accuracy: 1.0000 - val_loss: 8.0892e-07
# Epoch 83/100
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.9624 - loss: 0.1188
# Epoch 83: val_loss did not improve from 0.00000
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 54s 123ms/step - accuracy: 0.9624 - loss: 0.1188 - val_accuracy: 0.9593 - val_loss: 0.2021
# Epoch 84/100
#   1/433 ━━━━━━━━━━━━━━━━━━━━ 22s 52ms/step - accuracy: 0.9844 - loss: 0.0411
# Epoch 84: val_loss did not improve from 0.00000
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 0s 99us/step - accuracy: 0.9844 - loss: 0.0411 - val_accuracy: 1.0000 - val_loss: 9.5525e-06
# Epoch 85/100
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - accuracy: 0.9631 - loss: 0.1175
# Epoch 85: val_loss did not improve from 0.00000
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 50s 114ms/step - accuracy: 0.9631 - loss: 0.1175 - val_accuracy: 0.9521 - val_loss: 0.1856
# Epoch 86/100
#   1/433 ━━━━━━━━━━━━━━━━━━━━ 21s 49ms/step - accuracy: 0.9688 - loss: 0.0714
# Epoch 86: val_loss did not improve from 0.00000
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 0s 101us/step - accuracy: 0.9688 - loss: 0.0714 - val_accuracy: 1.0000 - val_loss: 3.7806e-06
# Epoch 87/100
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - accuracy: 0.9650 - loss: 0.1127
# Epoch 87: val_loss did not improve from 0.00000
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 51s 116ms/step - accuracy: 0.9650 - loss: 0.1127 - val_accuracy: 0.9845 - val_loss: 0.0799
# Epoch 88/100
#   1/433 ━━━━━━━━━━━━━━━━━━━━ 22s 51ms/step - accuracy: 1.0000 - loss: 0.0107
# Epoch 88: val_loss did not improve from 0.00000
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 0s 101us/step - accuracy: 1.0000 - loss: 0.0107 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 89/100
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - accuracy: 0.9704 - loss: 0.0946
# Epoch 89: val_loss did not improve from 0.00000
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 51s 116ms/step - accuracy: 0.9704 - loss: 0.0946 - val_accuracy: 0.9521 - val_loss: 0.1385
# Epoch 90/100
#   1/433 ━━━━━━━━━━━━━━━━━━━━ 25s 58ms/step - accuracy: 1.0000 - loss: 0.0071
# Epoch 90: val_loss did not improve from 0.00000
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 0s 101us/step - accuracy: 1.0000 - loss: 0.0071 - val_accuracy: 1.0000 - val_loss: 1.7030e-08
# Epoch 91/100
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - accuracy: 0.9718 - loss: 0.0890
# Epoch 91: val_loss did not improve from 0.00000
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 50s 115ms/step - accuracy: 0.9718 - loss: 0.0891 - val_accuracy: 0.9793 - val_loss: 0.0748
# Epoch 92/100
#   1/433 ━━━━━━━━━━━━━━━━━━━━ 22s 52ms/step - accuracy: 0.9844 - loss: 0.0669
# Epoch 92: val_loss did not improve from 0.00000
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 0s 102us/step - accuracy: 0.9844 - loss: 0.0669 - val_accuracy: 1.0000 - val_loss: 3.0228e-07
# Epoch 93/100
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - accuracy: 0.9725 - loss: 0.0857
# Epoch 93: val_loss did not improve from 0.00000
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 51s 117ms/step - accuracy: 0.9725 - loss: 0.0857 - val_accuracy: 0.9835 - val_loss: 0.0580
# Epoch 94/100
#   1/433 ━━━━━━━━━━━━━━━━━━━━ 34s 79ms/step - accuracy: 0.9844 - loss: 0.0215
# Epoch 94: val_loss did not improve from 0.00000
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 0s 111us/step - accuracy: 0.9844 - loss: 0.0215 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 95/100
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 0.9670 - loss: 0.1013
# Epoch 95: val_loss did not improve from 0.00000
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 61s 140ms/step - accuracy: 0.9670 - loss: 0.1013 - val_accuracy: 0.9388 - val_loss: 0.2647
# Epoch 96/100
#   1/433 ━━━━━━━━━━━━━━━━━━━━ 28s 67ms/step - accuracy: 0.9219 - loss: 0.3052
# Epoch 96: val_loss did not improve from 0.00000
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 0s 113us/step - accuracy: 0.9219 - loss: 0.3052 - val_accuracy: 1.0000 - val_loss: 2.1287e-08
# Epoch 97/100
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.9708 - loss: 0.0954
# Epoch 97: val_loss did not improve from 0.00000
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 51s 117ms/step - accuracy: 0.9708 - loss: 0.0954 - val_accuracy: 0.9337 - val_loss: 0.3102
# Epoch 98/100
#   1/433 ━━━━━━━━━━━━━━━━━━━━ 22s 51ms/step - accuracy: 0.9531 - loss: 0.1450
# Epoch 98: val_loss did not improve from 0.00000
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 0s 97us/step - accuracy: 0.9531 - loss: 0.1450 - val_accuracy: 1.0000 - val_loss: 5.5347e-08
# Epoch 99/100
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - accuracy: 0.9727 - loss: 0.0820
# Epoch 99: val_loss did not improve from 0.00000
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 50s 114ms/step - accuracy: 0.9727 - loss: 0.0820 - val_accuracy: 0.9701 - val_loss: 0.1290
# Epoch 100/100
#   1/433 ━━━━━━━━━━━━━━━━━━━━ 22s 51ms/step - accuracy: 0.9375 - loss: 0.2143
# Epoch 100: val_loss did not improve from 0.00000
# 433/433 ━━━━━━━━━━━━━━━━━━━━ 0s 97us/step - accuracy: 0.9375 - loss: 0.2143 - val_accuracy: 1.0000 - val_loss: 3.3924e-05

# %%
# Training curves
import matplotlib.pyplot as plt

history_dict = history.history
loss_values = history_dict['loss']
val_loss_values = history_dict['val_loss']

epochs_x = range(1, len(loss_values) + 1)
plt.figure(figsize=(10,10))
plt.subplot(2,1,1)
plt.plot(epochs_x, loss_values, 'bo', label='Training loss')
plt.plot(epochs_x, val_loss_values, 'b', label='Validation loss')
plt.title('Training and validation Loss and Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.subplot(2,1,2)
acc_values = history_dict['accuracy']
val_acc_values = history_dict['val_accuracy']
plt.plot(epochs_x, acc_values, 'bo', label='Training acc')
plt.plot(epochs_x, val_acc_values, 'b', label='Validation acc')
#plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Acc')
plt.legend()
plt.show()

# %%
from tensorflow.keras.models import load_model

model = load_model('modelo-treimado.keras')

# %%
# Using the validation dataset
score = model.evaluate(validation_generator)
print('Val loss:', score[0])
print('Val accuracy:', score[1])
# Out:
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - accuracy: 0.9869 - loss: 0.0512
# Val loss: 0.06764394789934158
# Val accuracy: 0.9780979752540588

# %%
# Using the test dataset
score = model.evaluate(test_generator)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 11s 60ms/step - accuracy: 0.9946 - loss: 0.0200
# Test loss: 0.027669250965118408
# Test accuracy: 0.9914270639419556

# %%
import itertools

#Plot the confusion matrix. Set Normalize = True/False
def plot_confusion_matrix(cm, classes, normalize=True, title='Confusion matrix', cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    plt.figure(figsize=(10,10))
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        cm = np.around(cm, decimals=2)
        cm[np.isnan(cm)] = 0.0
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j],
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")
    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %%
# Some reports
from sklearn.metrics import classification_report, confusion_matrix
import numpy as np

#On test dataset
Y_pred = model.predict(test_generator)
y_pred = np.argmax(Y_pred, axis=1)
target_names = classes

#Confution Matrix
cm = confusion_matrix(test_generator.classes, y_pred)
plot_confusion_matrix(cm, target_names, normalize=False, title='Confusion Matrix')

#Classification Report
print('Classification Report')
print(classification_report(test_generator.classes, y_pred, target_names=target_names))
# Out:
# 181/181 ━━━━━━━━━━━━━━━━━━━━ 5s 30ms/step
# Classification Report
#               precision    recall  f1-score   support
#
#            A       0.99      0.99      0.99       579
#            B       1.00      1.00      1.00       562
#            C       1.00      0.99      1.00       583
#            D       1.00      1.00      1.00       550
#            E       1.00      1.00      1.00       574
#            F       0.99      0.99      0.99       450
#            G       1.00      1.00      1.00       550
#            I       1.00      1.00      1.00       550
#            L       0.99      1.00      1.00       550
#            M       0.99      1.00      0.99       550
#            N       1.00      0.99      0.99       550
#            O       1.00      1.00      1.00       550
#            P       1.00      1.00      1.00       550
#            Q       1.00      1.00      1.00       550
#            R       1.00      0.93      0.96       550
#            S       0.99      0.99      0.99       550
#            T       0.99      0.99      0.99       550
#            U       0.93      1.00      0.96       550
#            V       0.95      1.00      0.98       550
#            W       1.00      0.95      0.97       550
#            Y       1.00      1.00      1.00       550
#
#     accuracy                           0.99     11548
#    macro avg       0.99      0.99      0.99     11548
# weighted avg       0.99      0.99      0.99     11548
